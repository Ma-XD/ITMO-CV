# %% [markdown]
# # Colab template — ITMO-CV
#
# Шаблон для запуска любой лабораторной в Google Colab.
# Скопируй этот ноутбук, выбери `Runtime → Change runtime type → GPU` и выполни ячейки по порядку.

# %% [markdown]
# ## 1. Clone / Pull репозитория

# %%
import os

REPO_URL = "https://github.com/Ma-XD/ITMO-CV.git"
REPO_DIR = "/content/ITMO-CV"

if os.path.exists(REPO_DIR):
    # !cd {REPO_DIR} && git pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print(f"📂 Working dir: {os.getcwd()}")

# %% [markdown]
# ## 2. Setup (GPU, Drive, зависимости)

# %%
# !python colab_setup.py

# %% [markdown]
# ## 3. Verify окружения

# %%
from env_config import print_env
print_env()

# %% [markdown]
# ## 4. Работа с конкретным проектом

# %%
# === Здесь начинается работа с конкретным проектом ===
# PROJECT = "lab1_car_color"
# os.chdir(PROJECT)
# !python train.py
